# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import pandas as pd
from operator import itemgetter
from PIL import Image, ImageOps
import pytesseract
import pyocr
import pyocr.builders
import json
import sys
import os
import glob
import re
import math
import random
import itertools
import sympy as sy
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
# Out:
# /home/abababam1/.conda/envs/HandwrittenTextAlign/lib/python3.8/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
if __name__ == "__main__":
    main()
# Out:
# 283
# hough_lines_p:  605
# draw_cross_points: 320
# 210
# hough_lines_p:  615
# draw_cross_points: 240
# 259
# hough_lines_p:  581
# draw_cross_points: 352
# 259
# hough_lines_p:  480
# draw_cross_points: 356
# 283
# hough_lines_p:  438
# draw_cross_points: 319
# 210
# hough_lines_p:  688
# draw_cross_points: 627
# 283
# hough_lines_p:  499
# draw_cross_points: 321
# 283
# hough_lines_p:  503
# draw_cross_points: 320
# 283
# hough_lines_p:  505
# draw_cross_points: 355
# 283
# hough_lines_p:  568
# draw_cross_points: 446
# 283
# hough_lines_p:  492
# draw_cross_points: 297
# 283
# hough_lines_p:  504
# draw_cross_points: 369
# 283
# hough_lines_p:  624
# draw_cross_points: 312
# 283
# hough_lines_p:  493
# draw_cross_points: 375
# 283
# hough_lines_p:  530
# draw_cross_points: 421
# 236
# hough_lines_p:  587
# draw_cross_points: 398
# 236
# hough_lines_p:  441
# draw_cross_points: 449
# 259
# hough_lines_p:  592
# draw_cross_points: 348
# 259
# hough_lines_p:  548
# draw_cross_points: 313
# 259
# hough_lines_p:  517
# draw_cross_points: 349
# 236
# hough_lines_p:  580
# draw_cross_points: 414
# 259
# hough_lines_p:  518
# draw_cross_points: 331
# 259
# hough_lines_p:  595
# draw_cross_points: 405
# 259
# hough_lines_p:  528
# draw_cross_points: 294
# 283
# hough_lines_p:  449
# draw_cross_points: 296
# 236
# hough_lines_p:  684
# draw_cross_points: 411
# 236
# hough_lines_p:  538
# draw_cross_points: 374
# 283
# hough_lines_p:  459
# draw_cross_points: 302
# 236
# hough_lines_p:  613
# draw_cross_points: 395
# 236
# hough_lines_p:  479
# draw_cross_points: 395
# 210
# hough_lines_p:  415
# draw_cross_points: 241
# 210
# hough_lines_p:  490
# draw_cross_points: 140
# 210
# hough_lines_p:  475
# draw_cross_points: 160
# 210
# hough_lines_p:  965
# draw_cross_points: 515
# 210
# hough_lines_p:  822
# draw_cross_points: 590
# 210
# hough_lines_p:  990
# draw_cross_points: 505
# 210
# hough_lines_p:  729
# draw_cross_points: 257
# quadrilaterals Detection error
# 210
# hough_lines_p:  573
# draw_cross_points: 176
# quadrilaterals Detection error
# 210
# hough_lines_p:  785
# draw_cross_points: 545
# 259
# hough_lines_p:  591
# draw_cross_points: 332
# OCR Result: 'S3-67'
# 210
# hough_lines_p:  525
# draw_cross_points: 191
# OCR Result: 'S3-45'
# 210
# hough_lines_p:  739
# draw_cross_points: 562
# OCR Result: 'S3-65'
# 210
# hough_lines_p:  464
# draw_cross_points: 167
# OCR Result: 'S3-49'
# 210
# hough_lines_p:  424
# draw_cross_points: 124
# OCR Result: 'S3-63'
# 210
# hough_lines_p:  756
# draw_cross_points: 566
# OCR Result: 'S3-48'
# 210
# hough_lines_p:  925
# draw_cross_points: 637
# OCR Result: 'S3-47'
# 210
# hough_lines_p:  539
# draw_cross_points: 181
# OCR Result: 'S3-46'
# 210
# hough_lines_p:  565
# draw_cross_points: 216
# OCR Result: 'S3-62'
# 210
# hough_lines_p:  978
# draw_cross_points: 522
# OCR Result: 'S3-61'
# 210
# hough_lines_p:  812
# draw_cross_points: 586
# OCR Result: 'S3-66'
# 210
# hough_lines_p:  741
# draw_cross_points: 591
# OCR Result: 'S3-60'
# 210
# hough_lines_p:  834
# draw_cross_points: 787
# OCR Result: 'S3-64'
# 210
# hough_lines_p:  515
# draw_cross_points: 211
# OCR Result: 'S3-57'
# 210
# hough_lines_p:  723
# draw_cross_points: 588
# OCR Result: 'S2-93'
# 283
# hough_lines_p:  475
# draw_cross_points: 299
# OCR Result: 'S2-94'
# 236
# hough_lines_p:  526
# draw_cross_points: 410
# OCR Result: 'S2-106'
# 259
# hough_lines_p:  457
# draw_cross_points: 323
# OCR Result: 'S2-105'
# 259
# hough_lines_p:  479
# draw_cross_points: 352
# OCR Result: 'S2-83'
# 259
# hough_lines_p:  427
# draw_cross_points: 315
# OCR Result: 'S2-102'
# 259
# hough_lines_p:  692
# draw_cross_points: 343
# OCR Result: 'S2-89'
# 259
# hough_lines_p:  541
# draw_cross_points: 367
# OCR Result: 'S2-84'
# 236
# hough_lines_p:  558
# draw_cross_points: 384
# OCR Result: 'S2-100'
# 236
# hough_lines_p:  604
# draw_cross_points: 418
# OCR Result: 'S2-98'
# 283
# hough_lines_p:  458
# draw_cross_points: 300
# OCR Result: 'S2-19'
# 259
# hough_lines_p:  531
# draw_cross_points: 399
# OCR Result: 'S2-81'
# 259
# hough_lines_p:  533
# draw_cross_points: 351
# OCR Result: 'S2-108'
# 236
# hough_lines_p:  643
# draw_cross_points: 388
# OCR Result: 'S2-90'
# 271
# hough_lines_p:  455
# draw_cross_points: 321
# OCR Result: 'S2-97'
# 236
# hough_lines_p:  629
# draw_cross_points: 414
# OCR Result: 'S2-95'
# 259
# hough_lines_p:  494
# draw_cross_points: 347
# OCR Result: 'S2-92'
# 236
# hough_lines_p:  614
# draw_cross_points: 382
# OCR Result: 'S2-87'
# 259
# hough_lines_p:  503
# draw_cross_points: 320
# OCR Result: 'S2-91'
# 259
# hough_lines_p:  532
# draw_cross_points: 352
# OCR Result: 'S2-80'
# 236
# hough_lines_p:  860
# draw_cross_points: 409
# OCR Result: 'S2-116'
# 236
# hough_lines_p:  440
# draw_cross_points: 395
# OCR Result: 'S2-85'
# 259
# hough_lines_p:  500
# draw_cross_points: 349
# OCR Result: 'S2-88'
# 236
# hough_lines_p:  393
# draw_cross_points: 199
# OCR Result: 'S2-82'
# 259
# hough_lines_p:  624
# draw_cross_points: 312
# OCR Result: 'S2-114'
# 271
# hough_lines_p:  408
# draw_cross_points: 329
# OCR Result: 'S2-96'
# 271
# hough_lines_p:  547
# draw_cross_points: 317
# OCR Result: 'S2-117'
# 283
# hough_lines_p:  657
# draw_cross_points: 305
# OCR Result: 'S2-99'
# 236
# hough_lines_p:  709
# draw_cross_points: 371
# OCR Result: 'S2-103'
# 236
# hough_lines_p:  514
# draw_cross_points: 476
# OCR Result: 'S2-107'
# 259
# hough_lines_p:  484
# draw_cross_points: 315
# OCR Result: 'S2-104'
# 236
# hough_lines_p:  490
# draw_cross_points: 420
# OCR Result: 'S2-101'
# 236
# hough_lines_p:  633
# draw_cross_points: 430
# OCR Result: 'S2-86'
# 259
# hough_lines_p:  511
# draw_cross_points: 344
# OCR Result: 'S1-15'
# 283
# hough_lines_p:  568
# draw_cross_points: 300
# OCR Result: 'S1-10'
# 283
# hough_lines_p:  564
# draw_cross_points: 290
# OCR Result: 'S1-3'
# 283
# hough_lines_p:  524
# draw_cross_points: 301
# OCR Result: 'S1-5'
# 283
# hough_lines_p:  538
# draw_cross_points: 297
# OCR Result: 'S1-13'
# 283
# hough_lines_p:  550
# draw_cross_points: 338
# OCR Result: 'S1-9'
# 283
# hough_lines_p:  513
# draw_cross_points: 351
# OCR Result: 'S1-23'
# 283
# hough_lines_p:  618
# draw_cross_points: 351
# OCR Result: 'S1-2'
# 283
# hough_lines_p:  548
# draw_cross_points: 322
# OCR Result: 'S1-11'
# 283
# hough_lines_p:  449
# draw_cross_points: 302
# OCR Result: 'S1-'
# OCR Result: 'S1-19'
# 283
# hough_lines_p:  572
# draw_cross_points: 300
# OCR Result: 'S1-4'
# 283
# hough_lines_p:  398
# draw_cross_points: 343
# OCR Result: 'S1-16'
# 283
# hough_lines_p:  555
# draw_cross_points: 387
# OCR Result: 'S1-22'
# 283
# hough_lines_p:  617
# draw_cross_points: 300
# OCR Result: 'S1-12'
# 283
# hough_lines_p:  413
# draw_cross_points: 330
# OCR Result: 'S1-6'
# 283
# hough_lines_p:  296
# draw_cross_points: 187
# OCR Result: 'S1-18'
# 283
# hough_lines_p:  544
# draw_cross_points: 300
# OCR Result: 'S1-8'
# 283
# hough_lines_p:  653
# draw_cross_points: 301
# OCR Result: 'S1-20'
# 283
# hough_lines_p:  585
# draw_cross_points: 323
# OCR Result: 'S1-21'
# 283
# hough_lines_p:  537
# draw_cross_points: 300
# OCR Result: 'S2-10'
# 259
# hough_lines_p:  565
# draw_cross_points: 318
# OCR Result: 'S2-8'
# 236
# hough_lines_p:  568
# draw_cross_points: 405
# OCR Result: 'S2-11'
# 259
# hough_lines_p:  487
# draw_cross_points: 318
# OCR Result: 'S2-32'
# 236
# hough_lines_p:  457
# draw_cross_points: 360
# OCR Result: 'S2-30'
# 259
# hough_lines_p:  526
# draw_cross_points: 347
# OCR Result: 'S2-2'
# 283
# hough_lines_p:  536
# draw_cross_points: 294
# OCR Result: 'S2-16'
# 236
# hough_lines_p:  579
# draw_cross_points: 331
# OCR Result: 'S2-29'
# 236
# hough_lines_p:  683
# draw_cross_points: 408
# OCR Result: 'S2-24'
# 271
# hough_lines_p:  498
# draw_cross_points: 320
# OCR Result: 'S2-1'
# 236
# hough_lines_p:  665
# draw_cross_points: 411
# OCR Result: 'S2-13'
# 259
# hough_lines_p:  516
# draw_cross_points: 351
# OCR Result: 'S2-37'
# 259
# hough_lines_p:  588
# draw_cross_points: 342
# OCR Result: 'S2-42'
# 271
# hough_lines_p:  264
# draw_cross_points: 46
# OCR Result: 'S2-23'
# 259
# hough_lines_p:  552
# draw_cross_points: 339
# OCR Result: 'S2-33'
# 259
# hough_lines_p:  453
# draw_cross_points: 354
# OCR Result: 'S2-39'
# 259
# hough_lines_p:  545
# draw_cross_points: 326
# OCR Result: 'S2-28'
# 236
# hough_lines_p:  563
# draw_cross_points: 410
# OCR Result: 'S2-17'
# 259
# hough_lines_p:  555
# draw_cross_points: 365
# OCR Result: 'S2-25'
# 236
# hough_lines_p:  534
# draw_cross_points: 419
# OCR Result: 'S2-79'
# 236
# hough_lines_p:  626
# draw_cross_points: 412
# OCR Result: 'S2-31'
# 236
# hough_lines_p:  468
# draw_cross_points: 429
# OCR Result: 'S2-21'
# 283
# hough_lines_p:  540
# draw_cross_points: 289
# OCR Result: 'S2-19'
# 259
# hough_lines_p:  560
# draw_cross_points: 347
# OCR Result: 'S2-27'
# 236
# hough_lines_p:  595
# draw_cross_points: 373
# OCR Result: 'S2-22'
# 236
# hough_lines_p:  573
# draw_cross_points: 381
# OCR Result: 'S2-26'
# 283
# hough_lines_p:  538
# draw_cross_points: 300
# OCR Result: 'S2-14'
# 259
# hough_lines_p:  555
# draw_cross_points: 346
# OCR Result: 'S2-20'
# 236
# hough_lines_p:  599
# draw_cross_points: 366
# OCR Result: 'S2-15'
# 259
# hough_lines_p:  443
# draw_cross_points: 329
# OCR Result: 'S2-6'
# 259
# hough_lines_p:  492
# draw_cross_points: 357
# OCR Result: 'S2-18'
# 271
# hough_lines_p:  520
# draw_cross_points: 310
# OCR Result: 'S2-4'
# 236
# hough_lines_p:  640
# draw_cross_points: 414
# OCR Result: 'S2-3'
# 236
# hough_lines_p:  598
# draw_cross_points: 392
# OCR Result: 'S2-138'
# 271
# hough_lines_p:  434
# draw_cross_points: 320
# OCR Result: 'S2-134'
# 259
# hough_lines_p:  418
# draw_cross_points: 311
# OCR Result: 'S2-132'
# 236
# hough_lines_p:  671
# draw_cross_points: 385
# OCR Result: 'S2-124'
# 236
# hough_lines_p:  676
# draw_cross_points: 418
# OCR Result: 'S2-153'
# 259
# hough_lines_p:  440
# draw_cross_points: 357
# OCR Result: 'S2-144'
# 271
# hough_lines_p:  528
# draw_cross_points: 323
# OCR Result: 'S2-123'
# 236
# hough_lines_p:  545
# draw_cross_points: 391
# OCR Result: 'S2-151'
# 236
# hough_lines_p:  604
# draw_cross_points: 402
# OCR Result: 'S2-155'
# 259
# hough_lines_p:  450
# draw_cross_points: 305
# OCR Result: 'S2-122'
# 283
# hough_lines_p:  642
# draw_cross_points: 299
# OCR Result: 'S2-143'
# 259
# hough_lines_p:  473
# draw_cross_points: 351
# OCR Result: 'S2-128'
# 236
# hough_lines_p:  545
# draw_cross_points: 390
# OCR Result: 'S2-141'
# 283
# hough_lines_p:  490
# draw_cross_points: 292
# OCR Result: 'S2-147'
# 236
# hough_lines_p:  645
# draw_cross_points: 369
# OCR Result: 'S2-152'
# 236
# hough_lines_p:  890
# draw_cross_points: 421
# OCR Result: 'S2-142'
# 236
# hough_lines_p:  699
# draw_cross_points: 384
# OCR Result: 'S2-133'
# 259
# hough_lines_p:  454
# draw_cross_points: 358
# OCR Result: 'S2-146'
# 283
# hough_lines_p:  401
# draw_cross_points: 302
# OCR Result: 'S2-131'
# 259
# hough_lines_p:  431
# draw_cross_points: 337
# OCR Result: 'S2-148'
# 236
# hough_lines_p:  612
# draw_cross_points: 431
# OCR Result: 'S2-129'
# 259
# hough_lines_p:  534
# draw_cross_points: 357
# OCR Result: 'S2-150'
# 259
# hough_lines_p:  686
# draw_cross_points: 344
# OCR Result: 'S2-139'
# 259
# hough_lines_p:  512
# draw_cross_points: 350
# OCR Result: 'S2-137'
# 259
# hough_lines_p:  609
# draw_cross_points: 364
# OCR Result: 'S2-154'
# 259
# hough_lines_p:  511
# draw_cross_points: 319
# OCR Result: 'S2-130'
# 259
# hough_lines_p:  537
# draw_cross_points: 312
# OCR Result: 'S2-136'
# 236
# hough_lines_p:  441
# draw_cross_points: 309
# OCR Result: 'S2-140'
# 236
# hough_lines_p:  552
# draw_cross_points: 367
# OCR Result: 'S2-149'
# 236
# hough_lines_p:  668
# draw_cross_points: 415
# OCR Result: 'S2-135'
# 259
# hough_lines_p:  484
# draw_cross_points: 325
# OCR Result: 'S1-204'
# 283
# hough_lines_p:  560
# draw_cross_points: 505
# OCR Result: 'S1-199'
# 283
# hough_lines_p:  487
# draw_cross_points: 373
# OCR Result: 'S1-202'
# 283
# hough_lines_p:  450
# draw_cross_points: 265
# OCR Result: 'S1-194'
# 283
# hough_lines_p:  589
# draw_cross_points: 395
# OCR Result: 'S1-193'
# 283
# hough_lines_p:  485
# draw_cross_points: 286
# OCR Result: 'S1-186'
# 283
# hough_lines_p:  481
# draw_cross_points: 383
# OCR Result: 'S1-206'
# 283
# hough_lines_p:  475
# draw_cross_points: 391
# OCR Result: 'S1-196'
# 283
# hough_lines_p:  545
# draw_cross_points: 273
# OCR Result: 'S1-176'
# 283
# hough_lines_p:  510
# draw_cross_points: 398
# OCR Result: 'S1-200'
# 283
# hough_lines_p:  429
# draw_cross_points: 250
# OCR Result: 'S1-183'
# 283
# hough_lines_p:  461
# draw_cross_points: 275
# OCR Result: 'S1-201'
# 283
# hough_lines_p:  470
# draw_cross_points: 280
# OCR Result: 'S1-189'
# 283
# hough_lines_p:  456
# draw_cross_points: 302
# OCR Result: 'S1-197'
# 283
# hough_lines_p:  429
# draw_cross_points: 289
# OCR Result: 'S1-177'
# 283
# hough_lines_p:  507
# draw_cross_points: 371
# OCR Result: 'S1-185'
# 283
# hough_lines_p:  453
# draw_cross_points: 260
# OCR Result: 'S1-207'
# 283
# hough_lines_p:  479
# draw_cross_points: 343
# OCR Result: 'S1-203'
# 283
# hough_lines_p:  554
# draw_cross_points: 478
# OCR Result: 'S1-192'
# 283
# hough_lines_p:  467
# draw_cross_points: 271
# OCR Result: 'S1-188'
# 283
# hough_lines_p:  464
# draw_cross_points: 388
# OCR Result: 'S1-205'
# 283
# hough_lines_p:  406
# draw_cross_points: 259
# OCR Result: 'S1-184'
# 283
# hough_lines_p:  552
# draw_cross_points: 279
# OCR Result: 'S1-198'
# 283
# hough_lines_p:  636
# draw_cross_points: 628
# OCR Result: 'S1-208'
# 283
# hough_lines_p:  556
# draw_cross_points: 381
# OCR Result: 'S1-190'
# 283
# hough_lines_p:  420
# draw_cross_points: 305
# OCR Result: 'S1-195'
# 283
# hough_lines_p:  390
# draw_cross_points: 283
# OCR Result: 'S1-191'
# 283
# hough_lines_p:  552
# draw_cross_points: 411
# OCR Result: 'S2-180'
# 236
# hough_lines_p:  235
# draw_cross_points: 135
# OCR Result: 'S2-173'
# 236
# hough_lines_p:  616
# draw_cross_points: 417
# OCR Result: 'S2-190'
# 236
# hough_lines_p:  562
# draw_cross_points: 378
# OCR Result: 'S2-184'
# 236
# hough_lines_p:  429
# draw_cross_points: 281
# OCR Result: 'S2-158'
# 259
# hough_lines_p:  530
# draw_cross_points: 334
# OCR Result: 'S2-179'
# 259
# hough_lines_p:  459
# draw_cross_points: 318
# OCR Result: 'S2-176'
# 236
# hough_lines_p:  617
# draw_cross_points: 381
# OCR Result: 'S2-188'
# 236
# hough_lines_p:  490
# draw_cross_points: 382
# OCR Result: 'S2-191'
# 259
# hough_lines_p:  535
# draw_cross_points: 350
# OCR Result: 'S2-181'
# 259
# hough_lines_p:  518
# draw_cross_points: 344
# OCR Result: 'S27-192'
# OCR Result: 'S2-182'
# 259
# hough_lines_p:  512
# draw_cross_points: 348
# OCR Result: 'S2-174'
# 259
# hough_lines_p:  557
# draw_cross_points: 344
# OCR Result: 'S2-168'
# 271
# hough_lines_p:  630
# draw_cross_points: 310
# OCR Result: 'S2-187'
# 259
# hough_lines_p:  705
# draw_cross_points: 345
# OCR Result: 'S2-175'
# 236
# hough_lines_p:  577
# draw_cross_points: 440
# OCR Result: 'S2-157'
# 259
# hough_lines_p:  480
# draw_cross_points: 362
# OCR Result: 'S2-189'
# 283
# hough_lines_p:  462
# draw_cross_points: 300
# OCR Result: 'S2-178'
# 259
# hough_lines_p:  474
# draw_cross_points: 320
# OCR Result: 'S2-186'
# 271
# hough_lines_p:  461
# draw_cross_points: 318
# OCR Result: 'S2-160'
# 236
# hough_lines_p:  499
# draw_cross_points: 332
# OCR Result: 'S2-177'
# 259
# hough_lines_p:  455
# draw_cross_points: 355
# OCR Result: 'S2-169'
# 236
# hough_lines_p:  618
# draw_cross_points: 406
# OCR Result: 'S2-185'
# 259
# hough_lines_p:  474
# draw_cross_points: 366
# OCR Result: 'S2-167'
# 259
# hough_lines_p:  540
# draw_cross_points: 350
# OCR Result: 'S2-183'
# 259
# hough_lines_p:  723
# draw_cross_points: 326
# OCR Result: 'S2-166'
# 236
# hough_lines_p:  581
# draw_cross_points: 379
# OCR Result: 'S2-170'
# 283
# hough_lines_p:  572
# draw_cross_points: 299
# OCR Result: 'S2-172'
# 236
# hough_lines_p:  774
# draw_cross_points: 406
# OCR Result: 'S1-161'
# 283
# hough_lines_p:  587
# draw_cross_points: 368
# OCR Result: 'S1-147'
# 283
# hough_lines_p:  510
# draw_cross_points: 349
# OCR Result: 'S1-148'
# 283
# hough_lines_p:  446
# draw_cross_points: 287
# OCR Result: 'S1-139'
# 283
# hough_lines_p:  537
# draw_cross_points: 410
# OCR Result: 'S1-150'
# 283
# hough_lines_p:  677
# draw_cross_points: 656
# OCR Result: 'S1-141'
# 283
# hough_lines_p:  619
# draw_cross_points: 508
# OCR Result: 'S1-144'
# 283
# hough_lines_p:  551
# draw_cross_points: 427
# OCR Result: 'S1-152'
# 283
# hough_lines_p:  559
# draw_cross_points: 413
# OCR Result: 'S1-145'
# 283
# hough_lines_p:  431
# draw_cross_points: 261
# OCR Result: 'S1-151'
# 283
# hough_lines_p:  525
# draw_cross_points: 346
# OCR Result: 'S1-171'
# 283
# hough_lines_p:  503
# draw_cross_points: 343
# OCR Result: 'S1-156'
# 283
# hough_lines_p:  515
# draw_cross_points: 357
# OCR Result: 'S1-168'
# 283
# hough_lines_p:  568
# draw_cross_points: 369
# OCR Result: 'S1-165'
# 283
# hough_lines_p:  528
# draw_cross_points: 436
# OCR Result: 'S1-137'
# 283
# hough_lines_p:  558
# draw_cross_points: 371
# OCR Result: 'S1-162'
# 283
# hough_lines_p:  644
# draw_cross_points: 337
# OCR Result: 'S1-142'
# 283
# hough_lines_p:  658
# draw_cross_points: 381
# OCR Result: 'S1-149'
# 283
# hough_lines_p:  575
# draw_cross_points: 380
# OCR Result: 'S1-140'
# 283
# hough_lines_p:  497
# draw_cross_points: 334
# OCR Result: 'S1-163'
# 283
# hough_lines_p:  613
# draw_cross_points: 307
# OCR Result: 'S1-170'
# 283
# hough_lines_p:  569
# draw_cross_points: 488
# OCR Result: 'S1-154'
# 283
# hough_lines_p:  531
# draw_cross_points: 461
# OCR Result: 'S1-160'
# 283
# hough_lines_p:  657
# draw_cross_points: 506
# OCR Result: 'S1-138'
# 283
# hough_lines_p:  551
# draw_cross_points: 366
# OCR Result: 'S1-158'
# 283
# hough_lines_p:  568
# draw_cross_points: 417
# OCR Result: 'S1-143'
# 283
# hough_lines_p:  567
# draw_cross_points: 512
# OCR Result: 'S1-157'
# 283
# hough_lines_p:  534
# draw_cross_points: 354
# OCR Result: 'S1-47'
# 283
# hough_lines_p:  587
# draw_cross_points: 370
# OCR Result: 'S1-42'
# 283
# hough_lines_p:  535
# draw_cross_points: 332
# OCR Result: 'S1-33'
# 283
# hough_lines_p:  436
# draw_cross_points: 399
# OCR Result: 'S1-46'
# 283
# hough_lines_p:  532
# draw_cross_points: 300
# OCR Result: 'S1-35'
# 283
# hough_lines_p:  556
# draw_cross_points: 312
# OCR Result: 'S1-49'
# 283
# hough_lines_p:  549
# draw_cross_points: 321
# OCR Result: 'S1-37'
# 283
# hough_lines_p:  584
# draw_cross_points: 321
# OCR Result: 'S1-45'
# 283
# hough_lines_p:  509
# draw_cross_points: 302
# OCR Result: 'S1-41'
# 283
# hough_lines_p:  493
# draw_cross_points: 323
# OCR Result: 'S1-55'
# 283
# hough_lines_p:  570
# draw_cross_points: 331
# OCR Result: 'S1-34'
# 283
# hough_lines_p:  462
# draw_cross_points: 300
# OCR Result: 'S1-43'
# 283
# hough_lines_p:  542
# draw_cross_points: 300
# OCR Result: 'S1-39'
# 283
# hough_lines_p:  505
# draw_cross_points: 300
# OCR Result: 'S1-51'
# 283
# hough_lines_p:  472
# draw_cross_points: 301
# OCR Result: 'S1-36'
# 283
# hough_lines_p:  485
# draw_cross_points: 330
# OCR Result: 'S1-48'
# 283
# hough_lines_p:  507
# draw_cross_points: 300
# OCR Result: 'S1-54'
# 283
# hough_lines_p:  536
# draw_cross_points: 351
# OCR Result: 'S1-44'
# 283
# hough_lines_p:  501
# draw_cross_points: 323
# OCR Result: 'S1-38'
# 283
# hough_lines_p:  556
# draw_cross_points: 300
# OCR Result: 'S1-40'
# 283
# hough_lines_p:  652
# draw_cross_points: 318
# OCR Result: 'S1-40'
# 283
# hough_lines_p:  563
# draw_cross_points: 384
# OCR Result: 'S1-46'
# 283
# hough_lines_p:  567
# draw_cross_points: 319
# OCR Result: 'S1-92'
# 283
# hough_lines_p:  437
# draw_cross_points: 333
# OCR Result: 'S1-53'
# 283
# hough_lines_p:  489
# draw_cross_points: 322
# OCR Result: 'S1-230'
# 283
# hough_lines_p:  521
# draw_cross_points: 511
# OCR Result: 'S1-209'
# 283
# hough_lines_p:  523
# draw_cross_points: 381
# OCR Result: 'S1-218'
# 283
# hough_lines_p:  591
# draw_cross_points: 520
# OCR Result: 'S1-226'
# 283
# hough_lines_p:  532
# draw_cross_points: 407
# OCR Result: 'S1-234'
# 283
# hough_lines_p:  605
# draw_cross_points: 575
# OCR Result: 'S1-229'
# 283
# hough_lines_p:  448
# draw_cross_points: 294
# OCR Result: 'S1-213'
# 283
# hough_lines_p:  502
# draw_cross_points: 380
# OCR Result: 'S1-228'
# 283
# hough_lines_p:  482
# draw_cross_points: 278
# OCR Result: 'S1-235'
# 283
# hough_lines_p:  505
# draw_cross_points: 427
# OCR Result: 'S1-231'
# 283
# hough_lines_p:  568
# draw_cross_points: 344
# OCR Result: 'S1-220'
# 283
# hough_lines_p:  453
# draw_cross_points: 311
# OCR Result: 'S1-210'
# 283
# hough_lines_p:  502
# draw_cross_points: 480
# OCR Result: 'S1-229'
# 283
# hough_lines_p:  566
# draw_cross_points: 362
# OCR Result: 'S1-212'
# 283
# hough_lines_p:  542
# draw_cross_points: 285
# OCR Result: 'S1-236'
# 283
# hough_lines_p:  504
# draw_cross_points: 363
# OCR Result: 'S1-214'
# 283
# hough_lines_p:  628
# draw_cross_points: 476
# OCR Result: 'S1-215'
# 283
# hough_lines_p:  515
# draw_cross_points: 392
# OCR Result: 'S1-232'
# 283
# hough_lines_p:  652
# draw_cross_points: 669
# OCR Result: 'S1-223'
# 283
# hough_lines_p:  602
# draw_cross_points: 475
# OCR Result: 'S1-219'
# 283
# hough_lines_p:  527
# draw_cross_points: 380
# OCR Result: 'S1-217'
# 283
# hough_lines_p:  624
# draw_cross_points: 424
# OCR Result: 'S1-224'
# 283
# hough_lines_p:  596
# draw_cross_points: 538
# OCR Result: 'S1-222'
# 283
# hough_lines_p:  645
# draw_cross_points: 671
# OCR Result: 'S1-233'
# 283
# hough_lines_p:  513
# draw_cross_points: 370
# OCR Result: 'S1-237'
# 283
# hough_lines_p:  483
# draw_cross_points: 397
# OCR Result: 'S1-216'
# 283
# hough_lines_p:  523
# draw_cross_points: 390
# OCR Result: 'S1-221'
# 283
# hough_lines_p:  558
# draw_cross_points: 421
# OCR Result: 'S1-211'
# 283
# hough_lines_p:  624
# draw_cross_points: 387
# OCR Result: 'S1-238'
# 283
# hough_lines_p:  565
# draw_cross_points: 492
# OCR Result: 'S1-87'
# 283
# hough_lines_p:  533
# draw_cross_points: 300
# OCR Result: 'S1-70'
# 283
# hough_lines_p:  613
# draw_cross_points: 299
# OCR Result: 'S1-97'
# 283
# hough_lines_p:  540
# draw_cross_points: 322
# OCR Result: 'S1-68'
# 283
# hough_lines_p:  612
# draw_cross_points: 318
# OCR Result: 'S1-92'
# 283
# hough_lines_p:  524
# draw_cross_points: 323
# OCR Result: 'S1-78'
# 283
# hough_lines_p:  713
# draw_cross_points: 350
# OCR Result: 'S1-65'
# 283
# hough_lines_p:  588
# draw_cross_points: 320
# OCR Result: 'S1-73'
# 283
# hough_lines_p:  583
# draw_cross_points: 321
# OCR Result: 'S1-96'
# 283
# hough_lines_p:  499
# draw_cross_points: 300
# OCR Result: 'S1-76'
# 283
# hough_lines_p:  620
# draw_cross_points: 296
# OCR Result: 'S1-74'
# 283
# hough_lines_p:  522
# draw_cross_points: 320
# OCR Result: 'S1-67'
# 283
# hough_lines_p:  528
# draw_cross_points: 302
# OCR Result: 'S1-91'
# 283
# hough_lines_p:  568
# draw_cross_points: 298
# OCR Result: 'S1-69'
# 283
# hough_lines_p:  537
# draw_cross_points: 299
# OCR Result: 'S1-66'
# 283
# hough_lines_p:  572
# draw_cross_points: 297
# OCR Result: 'S1-89'
# 283
# hough_lines_p:  515
# draw_cross_points: 323
# OCR Result: 'S1-94'
# 283
# hough_lines_p:  542
# draw_cross_points: 299
# OCR Result: 'S1-100'
# 283
# hough_lines_p:  556
# draw_cross_points: 296
# OCR Result: 'S1-98'
# 283
# hough_lines_p:  538
# draw_cross_points: 319
# OCR Result: 'S1-72'
# 283
# hough_lines_p:  514
# draw_cross_points: 301
# OCR Result: 'S1-88'
# 283
# hough_lines_p:  532
# draw_cross_points: 384
# OCR Result: 'S1-71'
# 283
# hough_lines_p:  579
# draw_cross_points: 350
# OCR Result: 'S1-79'
# 283
# hough_lines_p:  470
# draw_cross_points: 303
# OCR Result: 'S1-85'
# 283
# hough_lines_p:  726
# draw_cross_points: 317
# OCR Result: 'S1-93'
# 283
# hough_lines_p:  579
# draw_cross_points: 301
# OCR Result: 'S1-79'
# 283
# hough_lines_p:  439
# draw_cross_points: 343
# OCR Result: 'S1-80'
# 283
# hough_lines_p:  637
# draw_cross_points: 294
# OCR Result: 'S1-90'
# 283
# hough_lines_p:  596
# draw_cross_points: 299
# OCR Result: 'S1-86'
# 283
# hough_lines_p:  525
# draw_cross_points: 298
# OCR Result: 'S1-133'
# 283
# hough_lines_p:  524
# draw_cross_points: 317
# OCR Result: 'S1-111'
# 283
# hough_lines_p:  678
# draw_cross_points: 298
# OCR Result: 'S1-134'
# 283
# hough_lines_p:  550
# draw_cross_points: 300
# OCR Result: 'S1-130'
# 283
# hough_lines_p:  554
# draw_cross_points: 297
# OCR Result: 'S1-104'
# 283
# hough_lines_p:  601
# draw_cross_points: 299
# OCR Result: 'S1-136'
# 283
# hough_lines_p:  696
# draw_cross_points: 374
# OCR Result: 'S1-107'
# 283
# hough_lines_p:  576
# draw_cross_points: 304
# OCR Result: 'S1-114'
# 283
# hough_lines_p:  557
# draw_cross_points: 299
# OCR Result: 'S1-101'
# 283
# hough_lines_p:  573
# draw_cross_points: 303
# OCR Result: 'S1-103'
# 283
# hough_lines_p:  586
# draw_cross_points: 331
# OCR Result: 'S1-123'
# 283
# hough_lines_p:  539
# draw_cross_points: 301
# OCR Result: 'S1-126'
# 283
# hough_lines_p:  658
# draw_cross_points: 352
# OCR Result: 'S1-135'
# 283
# hough_lines_p:  473
# draw_cross_points: 296
# OCR Result: 'S1-128'
# 283
# hough_lines_p:  558
# draw_cross_points: 299
# OCR Result: 'S1-110'
# 283
# hough_lines_p:  591
# draw_cross_points: 292
# OCR Result: 'S1-109'
# 283
# hough_lines_p:  663
# draw_cross_points: 320
# OCR Result: 'S1-132'
# 283
# hough_lines_p:  529
# draw_cross_points: 327
# OCR Result: 'S1-112'
# 283
# hough_lines_p:  617
# draw_cross_points: 382
# OCR Result: 'S1-113'
# 283
# hough_lines_p:  604
# draw_cross_points: 319
# OCR Result: 'S1-108'
# 283
# hough_lines_p:  539
# draw_cross_points: 342
# OCR Result: 'S1-124'
# 283
# hough_lines_p:  629
# draw_cross_points: 289
# OCR Result: 'S1-129'
# 283
# hough_lines_p:  602
# draw_cross_points: 350
# OCR Result: 'S1-121'
# 283
# hough_lines_p:  570
# draw_cross_points: 318
# OCR Result: 'S1-131'
# 283
# hough_lines_p:  721
# draw_cross_points: 295
# OCR Result: 'S1-102'
# 283
# hough_lines_p:  618
# draw_cross_points: 349
# OCR Result: 'S1-127'
# 283
# hough_lines_p:  659
# draw_cross_points: 324
# OCR Result: 'S2-228'
# 236
# hough_lines_p:  701
# draw_cross_points: 460
# OCR Result: 'S2-209'
# 259
# hough_lines_p:  603
# draw_cross_points: 367
# OCR Result: 'S2-219'
# 236
# hough_lines_p:  541
# draw_cross_points: 380
# OCR Result: 'S2-215'
# 259
# hough_lines_p:  569
# draw_cross_points: 345
# OCR Result: 'S2-222'
# 259
# hough_lines_p:  506
# draw_cross_points: 341
# OCR Result: 'S2-216'
# 271
# hough_lines_p:  518
# draw_cross_points: 309
# OCR Result: 'S2-213'
# 283
# hough_lines_p:  472
# draw_cross_points: 298
# OCR Result: 'S2-227'
# 259
# hough_lines_p:  472
# draw_cross_points: 312
# OCR Result: 'S2-204'
# 236
# hough_lines_p:  616
# draw_cross_points: 394
# OCR Result: 'S2-195'
# 236
# hough_lines_p:  582
# draw_cross_points: 386
# OCR Result: 'S2-224'
# 236
# hough_lines_p:  662
# draw_cross_points: 391
# OCR Result: 'S2-206'
# 259
# hough_lines_p:  615
# draw_cross_points: 341
# OCR Result: 'S2-210'
# 271
# hough_lines_p:  446
# draw_cross_points: 317
# OCR Result: 'S2-217'
# 236
# hough_lines_p:  632
# draw_cross_points: 416
# OCR Result: 'S2-194'
# 283
# hough_lines_p:  447
# draw_cross_points: 302
# OCR Result: 'S2-197'
# 236
# hough_lines_p:  810
# draw_cross_points: 409
# OCR Result: 'S2-196'
# 236
# hough_lines_p:  590
# draw_cross_points: 413
# OCR Result: 'S2-225'
# 259
# hough_lines_p:  450
# draw_cross_points: 354
# OCR Result: 'S2-198'
# 259
# hough_lines_p:  519
# draw_cross_points: 349
# OCR Result: 'S2-21'
# 283
# hough_lines_p:  554
# draw_cross_points: 342
# OCR Result: 'S2-229'
# 259
# hough_lines_p:  530
# draw_cross_points: 338
# OCR Result: 'S2-208'
# 236
# hough_lines_p:  557
# draw_cross_points: 316
# OCR Result: 'S2-205'
# 259
# hough_lines_p:  527
# draw_cross_points: 346
# OCR Result: 'S2-212'
# 236
# hough_lines_p:  566
# draw_cross_points: 332
# OCR Result: 'S2-220'
# 236
# hough_lines_p:  698
# draw_cross_points: 403
# OCR Result: 'S2-226'
# 259
# hough_lines_p:  458
# draw_cross_points: 320
# OCR Result: 'S2-203'
# 259
# hough_lines_p:  525
# draw_cross_points: 313
# OCR Result: 'S2-214'
# 236
# hough_lines_p:  675
# draw_cross_points: 390
# OCR Result: 'S2-42'
# 271
# hough_lines_p:  511
# draw_cross_points: 313
# OCR Result: 'S2-47'
# 259
# hough_lines_p:  543
# draw_cross_points: 354
# OCR Result: 'S2-44'
# 236
# hough_lines_p:  510
# draw_cross_points: 382
# OCR Result: 'S2-64'
# 236
# hough_lines_p:  461
# draw_cross_points: 328
# OCR Result: 'S2-59'
# 259
# hough_lines_p:  580
# draw_cross_points: 309
# OCR Result: 'S2-63'
# 259
# hough_lines_p:  506
# draw_cross_points: 325
# OCR Result: 'S2-61'
# 259
# hough_lines_p:  591
# draw_cross_points: 368
# OCR Result: 'S2-45'
# 283
# hough_lines_p:  475
# draw_cross_points: 293
# OCR Result: 'S2-60'
# 236
# hough_lines_p:  646
# draw_cross_points: 387
# OCR Result: 'S2-43'
# 259
# hough_lines_p:  519
# draw_cross_points: 353
# OCR Result: 'S2-67'
# 259
# hough_lines_p:  697
# draw_cross_points: 356
# OCR Result: 'S2-49'
# 236
# hough_lines_p:  624
# draw_cross_points: 459
# OCR Result: 'S2-40'
# 236
# hough_lines_p:  495
# draw_cross_points: 309
# OCR Result: 'S2-51'
# 236
# hough_lines_p:  527
# draw_cross_points: 380
# OCR Result: 'S2-54'
# 259
# hough_lines_p:  775
# draw_cross_points: 352
# OCR Result: 'S2-46'
# 236
# hough_lines_p:  591
# draw_cross_points: 409
# OCR Result: 'S2-66'
# 271
# hough_lines_p:  525
# draw_cross_points: 313
# OCR Result: 'S2-68'
# 236
# hough_lines_p:  557
# draw_cross_points: 379
# OCR Result: 'S2-62'
# 259
# hough_lines_p:  765
# draw_cross_points: 349
# OCR Result: 'S2-48'
# 271
# hough_lines_p:  514
# draw_cross_points: 310
# OCR Result: 'S2-41'
# 259
# hough_lines_p:  461
# draw_cross_points: 378
# OCR Result: 'S2-53'
# 236
# hough_lines_p:  607
# draw_cross_points: 421
# OCR Result: 'S3-25'
# 210
# hough_lines_p:  661
# draw_cross_points: 570
# OCR Result: 'S3-16'
# 210
# hough_lines_p:  987
# draw_cross_points: 514
# OCR Result: 'S3-23'
# 210
# hough_lines_p:  425
# draw_cross_points: 125
# OCR Result: 'S3-4'
# 210
# hough_lines_p:  475
# draw_cross_points: 111
# OCR Result: 'S3-8'
# 210
# hough_lines_p:  900
# draw_cross_points: 621
# OCR Result: 'S3-12'
# 210
# hough_lines_p:  791
# draw_cross_points: 586
# OCR Result: 'S3-9'
# 210
# hough_lines_p:  823
# draw_cross_points: 630
# OCR Result: 'S3-13'
# 210
# hough_lines_p:  422
# draw_cross_points: 128
# OCR Result: 'S3-6'
# 210
# hough_lines_p:  878
# draw_cross_points: 697
# OCR Result: 'S3-15'
# 210
# hough_lines_p:  898
# draw_cross_points: 775
# OCR Result: '9.501187648456057'%
# Quad Detection: '0.4750593824228028'%

# %%
def main():
    sheet_path = '/data/matuzaki/sisha-split'
    save_dir = '/data2/abababam1/HandwrittenTextAlign/toda_char_imgs_new'
    
    OCRfailed = [['S1-125', 'sasame-1-2', 'xaah'], ['S3-5', 'sasame-3-1', 'xaae'], ['S2-230', 'bijogi-2-4', 'xaad'], ['S2-115', 'bijogi-2-1', 'xaba'], ['S1-14', 'miyamoto-1-1', 'xaan'], ['S3-30', 'sasame-3-1', 'xaad'], ['S1-17', 'miyamoto-1-1', 'xaaq'], ['S1-7', 'miyamoto-1-1', 'xaaa'], ['S1-155', 'bijogi-1-1', 'xaaw'], ['S1-159', 'bijogi-1-1', 'xabd'], ['S1-115', 'sasame-1-2', 'xaap'], ['S1-172', 'bijogi-1-1', 'xaad'], ['S1-77', 'sasame-1-1', 'xaap'], ['S1-95', 'sasame-1-1', 'xaac'], ['S1-227', 'bijogi-1-3', 'xaaf'], ['S2-70', 'sasame-2-3', 'xaar'], ['S2-56', 'sasame-2-3', 'xabf'], ['S2-57', 'sasame-2-3', 'xaam'], ['S2-58', 'sasame-2-3', 'xabc'], ['S2-71', 'sasame-2-3', 'xaai'], ['S2-145', 'bijogi-2-2', 'xaal'], ['S2-159', 'bijogi-2-3', 'xaax'], ['S2-211', 'bijogi-2-4', 'xaaw'], ['S2-65', 'sasame-2-3', 'xaaq'], ['S2-218', 'bijogi-2-4', 'xaac'], ['S2-223', 'bijogi-2-4', 'xaaa'], ['S2-5', 'sasame-2-3', 'xaad'], ['S2-50', 'sasame-2-3', 'xaaf'], ['S2-52', 'sasame-2-3', 'xaan'], ['S2-55', 'sasame-2-3', 'xabb'], ['S3-54', 'sasame-3-3', 'xaak'], ['S3-56', 'sasame-3-3', 'xaaq'], ['S3-58', 'sasame-3-3', 'xaat'], ['S3-17', 'sasame-3-1', 'xaam'], ['S3-52', 'sasame-3-3', 'xaad'], ['S3-53', 'sasame-3-3', 'xaac'], ['S3-55', 'sasame-3-3', 'xaal'], ['S3-59', 'sasame-3-3', 'xaas'], ['S3-7','sasame-3-1', 'xaag'], ['S2-207', 'bijogi-2-4', 'xaaq']]
    OCRfailed_path = remove_OCRfailed(OCRfailed)
    
    Quadfailed = []
    
    for ID, school, filename in OCRfailed:
        path = '/data/matuzaki/sisha-split/'+f'{school}.tif'+'/'+f'{filename}.tif'
        save_dir_imgs = os.path.join(save_dir, school)
        os.makedirs(save_dir_imgs, exist_ok=True)
        
        i = char_from_scan_OCRfailed(path, save_dir_imgs, ID, i = 1)
        
        if i == 0:
            print('quadrilaterals Detection error')
            Quadfailed.append([ID, school, filename])
    
    for path in glob.glob(f'{sheet_path}/*.tif/*.tif', recursive=True):
        if path in OCRfailed_path:
            continue
        school_class = os.path.splitext(path.split('/')[-2])[0]
        save_dir_imgs = os.path.join(save_dir, school_class)
        os.makedirs(save_dir_imgs, exist_ok=True)
        
        i = char_from_scan(path, save_dir_imgs, i = 1)
        
        if i == 0:
            print('quadrilaterals Detection error')
            Quadfailed.append(path)
            
    print(f"OCR Result: '{100 * len(OCRfailed)/len(glob.glob(f'{sheet_path}/*.tif/*.tif'))}'%")
    print(f"Quad Detection: '{100 * len(Quadfailed)/len(glob.glob(f'{sheet_path}/*.tif/*.tif'))}'%")
    
    #for path, save_dir_imgs in OCRfailed:
    #    print(f'path: {path},\n save_dir: {save_dir_imgs}')
    return 0

# %%
def char_from_scan(input_img, save_dir, i):
    file_name = os.path.splitext(os.path.basename(input_img))[0] # xaaa
    writer = file_name.split('_')[0]
    
    # スキャン結果を読み込み
    scan_img = Image.open(input_img)
    width, height = scan_img.size
    
    # 剪定範囲を設定(手書き字がある部分だけ取り出す)
    
    # シート名OCR
    try:
        numberd_img = scan_img.crop((0, 0, 1000, 350))
        number = pytesseract.image_to_string(numberd_img, lang = 'eng', config= \
                                                 '-c tessedit_char_whitelist="0123456789Ss-ー" --user-patterns PATH: /home/abababam1/HandwrittenTextAlign/toda_crop_imgs/userpattern.txt')
        if number == '':
            numberd_img = scan_img.crop((0, height - 300, width, height))
            number = pytesseract.image_to_string(numberd_img, lang = 'eng', config= \
                                                 '-c tessedit_char_whitelist="0123456789Ss-ー" --user-patterns PATH: /home/abababam1/HandwrittenTextAlign/toda_crop_imgs/userpattern.txt')
    except Exception as e:
        print(f"OCR failed: {e}")
        # OCR failed -> 別途手作業で対応
        return None
    
    # OCR結果下処理
    number = re.sub(r"[\n $']", '', number)
    # '-'が抜けてしまった時に対応
    if '-' not in number:
        number = number[:2] + '-' + number[2:]
    # 先頭をSに揃える
    if number[0] != 'S' and len(number) in [4, 5, 6]:
        number = re.sub('^[0-9s]', 'S', number)
        
    print(f"OCR Result: '{number}'")
    #numberd_img.save(f'/home/abababam1/HandwrittenTextAlign/test/number/{number}.png')
    
    # 例) S1-0, grade = 1, paper_number = 0
    if len(number) not in [4,5,6] or number[1] == '-':
        # OCR failed -> 別途手作業で対応
        return None
    grade = input_img.split('/')[4].split('-')[1]# ファイル名から #number[1]
    paper_number = number[3:None]
    
    if grade not in ['1', '2', '3'] or not re.match(r'^[1-9]\d{0,2}$', paper_number):
        # OCR failed -> 別途手作業で対応
        return None
    elif grade in ['1', '2']:
        design_number = (int(paper_number) % 24) or 24
    else:
        design_number = (int(paper_number) % 9) or 9
    

    # シート名ごとの原稿配置を取得
    params = load_genko_params(f'sisha-{grade}-genko-params.json'.format(grade))[design_number - 1]

    # crop_box作成
    cropbox = find_genko_box(scan_img, params)
    if cropbox is None:
        cropbox = find_largest_rectangle(scan_img, params)
    if cropbox is None:
        return 0
    cropped_img = scan_img.crop(cropbox) # crop の引数は ((left, upper, right, lower))
    
    # pillow to cv2
    image = np.array(cropped_img)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    # line、crosspoint検出のための前処理
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    gray = cv2.bitwise_not(gray)
    canny_edges = cv2.Canny(gray, 1, 100, apertureSize = 3)
    kernel = np.ones((3, 3), np.uint8)
    outLineImage = cv2.dilate(canny_edges, kernel, iterations=1)
    
    houghPList, mainlines = hough_lines_p(image, outLineImage, params)  # 直線抽出
    cross_points, image = draw_cross_points(image, houghPList, params)   # 直線リストから交点を描画
    if len(cross_points) == 0:
        cv2.imwrite('/home/abababam1/HandwrittenTextAlign/toda_crop_imgs/error_image/cross_points.jpg', img)
        return 0
    #cv2.imwrite("/home/abababam1/result_houghP_cross.png", image)  # ファイル保存
    
    # 正方形の頂点をピックアップ
    squares = find_squares(cross_points, params, cropbox)

    # 正方形でクロップ
    cropped_images = crop_squares(image, squares)
    
    if mainlines is not None:
        # 罫線を白塗り
        for line in mainlines:
            whiteline = 2
            lined_img = cv2.line(image, (line[0][0], line[0][1]), (line[0][2], line[0][3]), (255, 255, 255), whiteline)
        image = Image.fromarray(lined_img)

    
    # 個々の文字の画像を保存する
    save_path = os.path.join(save_dir, f'{file_name}_{number}')
    os.makedirs(save_path, exist_ok=True)
    for i, cropped_image in enumerate(cropped_images.values()):
        image = detect_line_in_char(cropped_image)
        
        #cropped_image.save((save_path)+'/'+'{:05d}.png'.format(i), 'PNG')
        output_path = f'{save_path}'+'/'+'{:05d}.png'.format(i)
        cv2.imwrite(output_path, image)
    return i

# %%
def char_from_scan_OCRfailed(input_img, save_dir, ID, i):
    file_name = os.path.splitext(os.path.basename(input_img))[0] # xaaa
    writer = file_name.split('_')[0]
    
    # スキャン結果を読み込み
    scan_img = Image.open(input_img)
    width, height = scan_img.size
    
    # 剪定範囲を設定(手書き字がある部分だけ取り出す)
    
    # 例) S1-0, grade = 1, paper_number = 0
    grade = ID[1]
    paper_number = ID.split('-')[1]
    if grade in ['1', '2']:
        design_number = (int(paper_number) % 24) or 24
    else:
        design_number = (int(paper_number) % 9) or 9
    

    # シート名ごとの原稿配置を取得
    params = load_genko_params(f'sisha-{grade}-genko-params.json'.format(grade))[design_number - 1]

    # crop_box作成
    cropbox = find_genko_box(scan_img, params)
    if cropbox is None:
        cropbox = find_largest_rectangle(scan_img, params)
    if cropbox is None:
        return 0
    cropped_img = scan_img.crop(cropbox) # crop の引数は ((left, upper, right, lower))
    
    # pillow to cv2
    image = np.array(cropped_img)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    # line、crosspoint検出のための前処理
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    gray = cv2.bitwise_not(gray)
    canny_edges = cv2.Canny(gray, 1, 100, apertureSize = 3)
    kernel = np.ones((3, 3), np.uint8)
    outLineImage = cv2.dilate(canny_edges, kernel, iterations=1)
    
    houghPList, mainlines = hough_lines_p(image, outLineImage, params)  # 直線抽出
    cross_points, pointed_image = draw_cross_points(image, houghPList, params)   # 直線リストから交点を描画
    if len(cross_points) == 0:
        cv2.imwrite('/home/abababam1/HandwrittenTextAlign/toda_crop_imgs/error_image/cross_points.jpg', img)
        return 0
    #cv2.imwrite("/home/abababam1/result_houghP_cross.png", image)  # ファイル保存
    
    # 正方形の頂点をピックアップ
    squares = find_squares(cross_points, params, cropbox)

    # 正方形でクロップ
    cropped_images = crop_squares(image, squares)
    
    if mainlines is not None:
        # 罫線を白塗り
        for line in mainlines:
            whiteline = 2
            lined_img = cv2.line(image, (line[0][0], line[0][1]), (line[0][2], line[0][3]), (255, 255, 255), whiteline)
        image = Image.fromarray(lined_img)

    
    # 個々の文字の画像を保存する
    save_path = os.path.join(save_dir, f'{file_name}_{ID}')
    os.makedirs(save_path, exist_ok=True)
    for i, cropped_image in enumerate(cropped_images.values()):
        image = detect_line_in_char(cropped_image)
        
        #cropped_image.save((save_path)+'/'+'{:05d}.png'.format(i), 'PNG')
        output_path = f'{save_path}'+'/'+'{:05d}.png'.format(i)
        cv2.imwrite(output_path, image)
    return i

# %%
def remove_OCRfailed(OCRfailed):
    OCRfailed_path = []
    for ID, school, filename in OCRfailed:
        path = '/data/matuzaki/sisha-split/'+f'{school}.tif'+'/'+f'{filename}.tif'
        OCRfailed_path.append(path)
    return OCRfailed_path

# 原稿配置のパラメータが入ったjsonファイルの読み込み
def load_genko_params(filename):
    with open(filename, 'r') as file:
        return json.load(file)
    
def check_genko_size_and_angle(hull, genko_1, genko_2):  
    quad = set()
    n = len(hull)
    x_max, x_min = 0, float('inf')
    y_max, y_min = 0, float('inf')
    genko_angle_list = []
    tate = 0
    yoko = 0
    for i in range(n):
        for j in range(i + 1, n):
            ij_distance = np.linalg.norm(hull[i][0] - hull[j][0])
            ij_width = abs(hull[i][0][0] - hull[j][0][0])
            ij_height = abs(hull[i][0][1] - hull[j][0][1])
            # 横
            if any(abs(ij_distance - henn) <= 50 for henn in [genko_1, genko_2]) and ij_height <= 20:
                yoko = 1
                quad.add(tuple(hull[i][0]))
                quad.add(tuple(hull[j][0]))
                x_max = max(x_max, hull[i][0][0], hull[j][0][0])
                x_min = min(x_min, hull[i][0][0], hull[j][0][0])
                y_max = max(y_max, hull[i][0][1], hull[j][0][1])
                y_min = min(y_min, hull[i][0][1], hull[j][0][1])
                #genko_angle = calculate_angle_yoko(hull[i][0][0], hull[j][0][0], hull[i][0][0], hull[j][0][0])
                #genko_angle_list.append(genko_angle)
            # 縦
            elif ij_width <= 20 and any(abs(ij_distance - henn) <= 50 for henn in [genko_1, genko_2]):
                tate = 1
                quad.add(tuple(hull[i][0]))
                quad.add(tuple(hull[j][0]))
                x_max = max(x_max, hull[i][0][0], hull[j][0][0])
                x_min = min(x_min, hull[i][0][0], hull[j][0][0])
                y_max = max(y_max, hull[i][0][1], hull[j][0][1])
                y_min = min(y_min, hull[i][0][1], hull[j][0][1])
                #genko_angle = calculate_angle_tate(hull[i][0][0], hull[j][0][0], hull[i][0][0], hull[j][0][0])
                #genko_angle_list.append(genko_angle)
    if yoko == 1 and tate == 1:
        # 四頂点と右上の座標
        #cropbox = (max(0, x_min + 5), max(0, y_min + 5), min(x_max - 5, 5000), min(y_max - 5, 6000))
        cropbox = (x_min + 0, y_min + 0, x_max - 0, y_max - 0)
        return quad, cropbox
    else:
        return quad, None

def find_genko_box(pillow_img, params):
    width, height = pillow_img.size
    nchars = params['nchars']
    ncols = params['ncols']
    char_width = params['char_width']
    sep_width = params['sep_width']
    
    # ピクセルに変換する
    dpi = 600
    char_size_px = int((char_width / 2.54) * dpi) # 236~
    sep_size_px = int((sep_width / 2.54) * dpi) # 47~
    
    
    #原稿用紙部分の面積
    best_area = (ncols * (char_size_px + sep_size_px) + sep_size_px) * (nchars * char_size_px)
    
    # Pillowの画像をNumPy配列に変換（RGB）
    img = np.array(pillow_img)

    # RGBをBGRに変換
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # エッジ検出
    edged = cv2.Canny(gray, 50, 150)

    # 輪郭を見つける
    contours, _ = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # 最大面積の四角形を見つける
    min_distance = float('inf')#width * height - best_area
    best_rect = None
    for contour in contours:
        
        # 凸包近似
        hull = cv2.convexHull(contour)
        area = cv2.contourArea(hull)
        
        distance = abs(area - best_area)
        if distance < min_distance:
            min_distance = distance
            best_rect = hull
        
    if best_rect is not None:
        cv2.drawContours(img, [best_rect], -1, (0, 255, 0), 2)  # 緑色の線で描画
        genko_1 = ncols * (char_size_px + sep_size_px) + sep_size_px
        genko_2 = nchars * char_size_px
        quad, cropbox = check_genko_size_and_angle(best_rect, genko_1, genko_2)
        for i in range(len(quad)):
            cv2.circle(img, list(quad)[i], 10, (0, 0, 255), thickness=5, lineType=cv2.LINE_8, shift=0)
        for i in range(len(best_rect)):
            cv2.circle(img, tuple(best_rect[i][0]), 5, (255, 0, 0), thickness=5, lineType=cv2.LINE_8, shift=0)
        #cv2.imwrite('/home/abababam1/result_image_.jpg', img)

        if cropbox is not None:
            return cropbox
        else:
            #print('quadrilaterals Detection error')
            #cv2.imwrite(f'/home/abababam1/HandwrittenTextAlign/toda_crop_imgs/error_image/quad_error.jpg', img)
            return None
    else:
        print('hull Detection error')
        cv2.imwrite('/home/abababam1/HandwrittenTextAlign/toda_crop_imgs/error_image/hull_error.jpg', img)
        return None
    
def find_largest_rectangle(pillow_img, params):
    # 読み込み
    width, _ = pillow_img.size
    nchars = params['nchars']
    ncols = params['ncols']
    char_width = params['char_width']
    sep_width = params['sep_width']
    
    # ピクセルに変換する
    dpi = 600
    char_size_px = int((char_width / 2.54) * dpi)
    sep_size_px = int((sep_width / 2.54) * dpi)
    
    #原稿用紙部分の面積
    best_area = (ncols * (char_size_px + sep_size_px) + sep_size_px) * (nchars * char_size_px)
    
    # Pillowの画像をNumPy配列に変換（RGB）
    img = np.array(pillow_img)

    # RGBをBGRに変換
    img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # エッジ検出
    edged = cv2.Canny(gray, 50, 150)

    # 輪郭を見つける
    contours, _ = cv2.findContours(edged, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    # 最大面積の四角形を見つける
    min_distance = float('inf')
    best_rect = None
    best_angle = 0
    for contour in contours:
        rect = cv2.minAreaRect(contour)  # 最小の回転された矩形を取得
        box = cv2.boxPoints(rect)  # 回転された矩形の四角を取得
        box = np.int0(box)  # 座標を整数に変換
        area = cv2.contourArea(box)
        distance = abs(area - best_area)
        if distance < min_distance:
            min_distance = distance
            best_rect = box
    if best_rect is not None:
        # バウンディングボックスの座標でクロップ
        x, y, w, h = cv2.boundingRect(best_rect)
        cropbox = (x, y, x+w, y+h)
        return cropbox
    else:
        return None

def detect_chars_from_cropbox(img, params, cropbox):
    
    muki = params['muki']
    nchars = params['nchars']
    ncols = params['ncols']
    char_width = params['char_width']
    sep_width = params['sep_width']
    
    # ピクセルに変換する
    dpi = 600
    char_size_px = int((char_width / 2.54) * dpi)
    sep_size_px = int((sep_width / 2.54) * dpi)
    
    chars = []
    
    if muki == 'tate': # 右から
        for cols in range(int(ncols)):
            for n in range(int(nchars)):
                x_right = cropbox[2] - sep_size_px - cols * (char_size_px + sep_size_px)
                y_upper = cropbox[1] + n * char_size_px
                
                x_left = x_right - char_size_px
                y_lower = y_upper + char_size_px
                char = img.crop((x_left+2, y_upper+2, x_right-2, y_lower-2))
                chars.append(char)
    elif muki == 'yoko': # 左から
        for cols in range(int(ncols)):
            for n in range(int(nchars)):
                x_left = cropbox[0] + n * char_size_px
                y_upper = cropbox[1] + sep_size_px + cols * (char_size_px + sep_size_px)
                
                x_right = x_left + char_size_px
                y_lower = y_upper + char_size_px
                char = img.crop((x_left+2, y_upper+2, x_right-2, y_lower-2))
                chars.append(char)
    return chars


def detect_line_in_char(char_img): # cleaner
    image = np.array(char_img)
    img = None

    # 検出しやすくするために二値化
    #th, judge_img = cv2.threshold(judge_img, 1, 255, cv2.THRESH_BINARY)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    gray = cv2.bitwise_not(gray)
    canny_edges = cv2.Canny(gray, 1, 100, apertureSize = 3)
    kernel = np.ones((3, 3), np.uint8)
    outLineImage = cv2.dilate(canny_edges, kernel, iterations=1)
    
    height, width = gray.shape
    
    minlength = width * 0.90
    gap = 30

    lines = []
    lines = cv2.HoughLinesP(outLineImage, rho=1, theta=np.pi/360, threshold=100, minLineLength=minlength, maxLineGap=gap)
    
    detect_length = width * 0.05
    if lines is not None:
        for line in lines:
            x1, y1, x2, y2 = line[0]
            if (abs(y1 - y2) < 5 and (y1 <= detect_length or y2 >= height-detect_length)) or (abs(x1 - x2) < 5 and (x1 <= detect_length or x2 >= width-detect_length)):
                whiteline = 2
                img = cv2.line(image, (line[0][0], line[0][1]), (line[0][2], line[0][3]), (255, 255, 255), whiteline)
        if img is not None:
            return img#Image.fromarray(img)
        else:
            return char_img
    else:
        return char_img

# 確率的ハフ変換で直線を抽出する関数
def hough_lines_p(image, outLineImage, params):
    char_width = params['char_width']
    dpi = 600
    char_size_px = int((char_width / 2.54) * dpi)
    
    lineList = []
    main_lines = None
    # 確率的ハフ変換で直線を抽出
    lines = cv2.HoughLinesP(outLineImage, rho=1, theta=np.pi/360, threshold=150, minLineLength=char_size_px*0.9, maxLineGap=5)
    if lines is not None:
        print("hough_lines_p: ", len(lines))

        main_lines = cv2.HoughLinesP(outLineImage, rho=1, theta=np.pi/360, threshold=150, minLineLength=char_size_px*5, maxLineGap=5)
        
        for line in lines:
            x1, y1, x2, y2 = line[0]
            lineList.append((x1, y1, x2, y2))
            #cv2.line(image,(x1,y1),(x2,y2),(0,255,0),2) # 緑色で直線を引く

        return lineList, main_lines
    else:
        return lineList, main_lines


# 交点を描画する関数
def draw_cross_points(image, lineList, params):
    sep_width = params['sep_width']
    dpi = 600
    sep_size_px = int((sep_width / 2.54) * dpi)
    
    size = len(lineList)
    cross_points = []
    cnt = 0
    for i in range(size-1):
        for j in range(i+1, size):
            pointA = (lineList[i][0], lineList[i][1])
            pointB = (lineList[i][2], lineList[i][3])
            pointC = (lineList[j][0], lineList[j][1])
            pointD = (lineList[j][2], lineList[j][3])
            ret, cross_point = calc_cross_point(pointA, pointB, pointC, pointD) # 交点を計算
            if ret:
                # 交点が取得できた場合でも画像の範囲外のものは除外
                # if (cross_point[0] >= 0 + 0.5*sep_size_px) and (cross_point[0] <= image.shape[1] - 0.5*sep_size_px) and (cross_point[1] >= 0) and (cross_point[1] <= image.shape[0]):
                if (cross_point[0] >= 0) and (cross_point[0] <= image.shape[1]) and (cross_point[1] >= 0) and (cross_point[1] <= image.shape[0]):
                    #cv2.circle(image, (cross_point[0],cross_point[1]), 2, (255,0,0), 3) # 交点を青色で描画
                    cnt = cnt + 1
                    cross_points.append(cross_point)
    # 近くの座標をクラスタリングしてまとめる
    cross_points = cluster_and_round_points(cross_points)
    # x,y軸の座標をクラスタリングしてまとめる
    #cross_points = cluster_x_coordinates(cross_points, eps=3)
    #cross_points = cluster_y_coordinates(cross_points, eps=3)
    for cross_point in cross_points:
        #if (cross_point[0] >= 0 + 0.5*sep_size_px) and (cross_point[0] <= image.shape[1] - 0.5*sep_size_px) and (cross_point[1] >= 0) and (cross_point[1] <= image.shape[0]):
        if (cross_point[0] >= 0) and (cross_point[0] <= image.shape[1]) and (cross_point[1] >= 0) and (cross_point[1] <= image.shape[0]):    
            cv2.circle(image, (cross_point[0],cross_point[1]), 2, (255,0,0), 3) # 交点を青色で描画
    #print("draw_cross_points:", cnt)
    print("draw_cross_points:", len(cross_points))
    return cross_points, image

# 線分ABと線分CDの交点を求める関数
def calc_cross_point(pointA, pointB, pointC, pointD):
    cross_points = [0,0]
    bunbo = (pointB[0] - pointA[0]) * (pointD[1] - pointC[1]) - (pointB[1] - pointA[1]) * (pointD[0] - pointC[0])

    # 直線が平行な場合
    if (bunbo == 0):
        return False, cross_points

    vectorAC = ((pointC[0] - pointA[0]), (pointC[1] - pointA[1]))
    r = ((pointD[1] - pointC[1]) * vectorAC[0] - (pointD[0] - pointC[0]) * vectorAC[1]) / bunbo
    s = ((pointB[1] - pointA[1]) * vectorAC[0] - (pointB[0] - pointA[0]) * vectorAC[1]) / bunbo

    # 水平な線分がある場合、拡張された範囲でチェックする
    if abs(pointA[1] - pointB[1]) <= 1:
        if (r < -0.5*15) or (r > 1.5*15) or (s < 0) or (s > 1):
            return False, cross_points
    elif abs(pointC[1] - pointD[1]) <= 1:
        if (r < 0) or (r > 1) or (s < -0.5*15) or (s > 1.5*15):
            return False, cross_points
    else:
        if (r < 0) or (r > 1) or (s < 0) or (s > 1):
            return False, cross_points
    
    # 線分AB、線分AC上に存在しない場合
    #if (r <= -0.5) or (1.5 <= r) or (s <= -0.5) or (1.5 <= s):
    #    return False, cross_points
    
    # 直角に近いかどうかを判定するための内積計算
    vectorAB = (pointB[0] - pointA[0], pointB[1] - pointA[1])
    vectorCD = (pointD[0] - pointC[0], pointD[1] - pointC[1])
    dot_product = vectorAB[0] * vectorCD[0] + vectorAB[1] * vectorCD[1]
    magAB = np.sqrt(vectorAB[0]**2 + vectorAB[1]**2)
    magCD = np.sqrt(vectorCD[0]**2 + vectorCD[1]**2)
    cos_theta = dot_product / (magAB * magCD)

    # 角度が85度から95度の範囲にあるかチェック
    if not (-0.05 <= cos_theta <= 0.05):
        return False, cross_points

    # rを使った計算の場合
    distance = ((pointB[0] - pointA[0]) * r, (pointB[1] - pointA[1]) * r)
    cross_points = (int(pointA[0] + distance[0]), int(pointA[1] + distance[1]))

    # sを使った計算の場合
    # distance = ((pointD[0] - pointC[0]) * s, (pointD[1] - pointC[1]) * s)
    # cross_points = (int(pointC[0] + distance[0]), int(pointC[1] + distance[1]))

    return True, cross_points

def cluster_and_round_points(points, eps=3, min_samples=1):
    if len(points) == 0:
        return np.array(points)
    points_array = np.array(points)
    clustering = DBSCAN(eps=eps, min_samples=min_samples).fit(points_array)
    labels = clustering.labels_
    unique_labels = set(labels)
    
    clustered_points = []
    for label in unique_labels:
        if label == -1:
            continue
        cluster = points_array[labels == label]
        centroid = np.round(cluster.mean(axis=0)).astype(int)
        clustered_points.append(centroid)
    
    return np.array(clustered_points)

def cluster_x_coordinates(points, eps=2, min_samples=1):
    if len(points) == 0:
        return np.array(points)
    # x座標のみを取り出してクラスタリング # ⚠️ 同じyの値に対して
    x_coords = points[:, 0].reshape(-1, 1)
    clustering = DBSCAN(eps=eps, min_samples=min_samples).fit(x_coords)
    labels = clustering.labels_
    unique_labels = set(labels)
    
    clustered_points = points.copy()
    for label in unique_labels:
        if label == -1:
            continue
        # クラスター内のx座標をまとめ、その平均値を新しいx座標とする
        cluster_indices = np.where(labels == label)[0]
        mean_x = np.round(np.mean(points[cluster_indices, 0])).astype(int)
        clustered_points[cluster_indices, 0] = mean_x
    
    return clustered_points

def cluster_y_coordinates(points, eps=2, min_samples=1):
    if len(points) == 0:
        return np.array(points)
    # y座標のみを取り出してクラスタリング
    y_coords = points[:, 1].reshape(-1, 1)
    clustering = DBSCAN(eps=eps, min_samples=min_samples).fit(y_coords)
    labels = clustering.labels_
    unique_labels = set(labels)
    
    clustered_points = points.copy()
    for label in unique_labels:
        if label == -1:
            continue
        # クラスター内のy座標をまとめ、その平均値を新しいy座標とする # ⚠️ 同じxの値に対して
        cluster_indices = np.where(labels == label)[0]
        mean_y = np.round(np.mean(points[cluster_indices, 1])).astype(int)
        clustered_points[cluster_indices, 1] = mean_y
    
    return clustered_points

# 一点固定後に他三点を探す
def is_square(cross_points, i, n, square, char_size_px, tolerance):
    p1 = cross_points[i]
    square.append(p1)
    for j in range(i+1, n): # 下/左
        p2 = cross_points[j]
        d2 = np.linalg.norm(np.array(p1) - np.array(p2))
        if abs(d2 - char_size_px) <= tolerance:
            square.append(p2)
        else:
            continue
        for k in range(j+1, n): # 左/右
            p3 = cross_points[k]
            d3 = np.linalg.norm(np.array(p1) - np.array(p3))
            if abs(d3 - char_size_px) <= tolerance:
                square.append(p3)
            else:
                continue
            for l in range(k+1, n): # 左下/右下
                p4 = cross_points[l]
                d4 = np.linalg.norm(np.array(p1) - np.array(p4))
                if abs(d4 - np.sqrt(2) * char_size_px) <= tolerance:
                    square.append(p4)
                    if len(square) >= 3:
                        return square
                else:
                    continue

def find_squares(cross_points, params, cropbox):
    squares = dict()
    n = len(cross_points)
    muki = params['muki']
    nchars = params['nchars']
    ncols = params['ncols']
    char_width = params['char_width']
    sep_width = params['sep_width']
    
    # ピクセルに変換する
    dpi = 600
    char_size_px = int((char_width / 2.54) * dpi)
    sep_size_px = int((sep_width / 2.54) * dpi)
    
    # sep_width未満にするべき
    tolerance = 5
            
    if muki == 'tate':
        # ソート: x は降順、y は昇順
        cross_points = sorted(cross_points, key=lambda point: (-point[0], point[1]))
        # p1: 一点目
        for i in range(n):
            p1 = cross_points[i]
            # cropboxの左端or下限
            if abs(p1[0] - cropbox[0]) <= tolerance or abs(p1[1] - cropbox[3]) <= tolerance:
                continue
            else:
                square = is_square(cross_points, i, n, [], char_size_px, tolerance)
                if square:
                    squares[i] = square   
    else:
        # ソート: y を優先して昇順、その次に x を昇順にソート
        cross_points = sorted(cross_points, key=lambda point: (point[1], point[0]))
        # p1: 一点目
        for i in range(n):
            p1 = cross_points[i]
            # cropboxの左端or下限
            if abs(p1[0] - cropbox[0]) <= tolerance or abs(p1[1] - cropbox[3]) <= tolerance:
                continue
            else:
                square = is_square(cross_points, i, n, [], char_size_px, tolerance)
                if square:
                    squares[i] = square 
    return squares

def crop_squares(image, squares):
    #char_width = params['char_width']
    #dpi = 600
    #char_size_px = int((char_width / 2.54) * dpi)
    
    cropped_images = dict()
    for i, square in squares.items():
        x_coords = [int(p[0]) for p in square]
        y_coords = [int(p[1]) for p in square]
        min_x, max_x = min(x_coords), max(x_coords)
        min_y, max_y = min(y_coords), max(y_coords)
        
        #if (max_x - min_x) == side_length and (max_y - min_y) == side_length:
        cropped_image = image[min_y:max_y, min_x:max_x]

        #left = sorted(approx, key=lambda x: x[0])[:2]
        #right = sorted(approx, key=lambda x: x[0])[2:]
        #left_down = sorted(left, key=lambda x: x[0][1])[0]
        #left_up = sorted(left, key=lambda x: x[0][1])[1]
        #right_down = sorted(right, key=lambda x: x[0][1])[0]
        #right_up = sorted(right, key=lambda x: x[0][1])[1]
        
        #left_down = [min_x, max_y]
        #right_down = [max_x, max_y]
        #right_up = [max_x, min_y]
        #left_up = [min_x, min_y]

        #perspective_base = np.float32([left_down, right_down, right_up, left_up])
        #perspective = np.float32([[0, 0], [char_size_px, 0], [char_size_px, char_size_px], [0, char_size_px]]) # ⚠️

        #psp_matrix = cv2.getPerspectiveTransform(perspective_base, perspective) # 引数はfloat32のnumpy配列である必要
        #square_image = cv2.warpPerspective(cropped_image, psp_matrix, (square_size, square_size))
        
        cropped_images[i] = cropped_image
    return cropped_images

def PerspectiveTransform(img, square, square_size):
    left_down, right_down, right_up, left_up = square
    # 台形の4点
    perspective_base = np.float32([left_down, right_down, right_up, left_up])

    # 変換先の座標（正方形の4点）
    perspective = np.float32([
        [0, square_size], 
        [square_size, square_size], 
        [square_size, 0], 
        [0, 0]
    ])
    psp_matrix = cv2.getPerspectiveTransform(perspective_base, perspective)
    square_img = cv2.warpPerspective(img, psp_matrix, (square_size, square_size))
    
    return square_img

# %%
import numpy as np
import cv2

IMAGE_PATH = "/data/matuzaki/sisha-split/sasame-3-3.tif/xaau.tif" # 読み込む画像
grade = 3
design_number = 57 % 9
params = load_genko_params(f'sisha-{grade}-genko-params.json'.format(grade))[design_number - 1]
# 正方形の辺の長さを指定
char_width = params['char_width']
sep_width = params['sep_width']

# ピクセルに変換する
dpi = 600
char_size_px = int((char_width / 2.54) * dpi)
sep_size_px = int((sep_width / 2.54) * dpi)
save_path = "/home/abababam1/HandwrittenTextAlign/test/Anna/output_xaau"

def test():
    #image  = cv2.imread(IMAGE_PATH) # 画像読み込み
    #image2 = cv2.imread(IMAGE_PATH) # 画像読み込み
    
    scan_img = Image.open(IMAGE_PATH)
    cropbox = find_genko_box(scan_img, params)
    cropped_img = scan_img.crop(cropbox)
    image = np.array(cropped_img)
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    image2 = np.copy(image)
    
    gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) # グレースケール化
    gray = cv2.bitwise_not(gray)
    canny_edges = cv2.Canny(gray, 1, 100, apertureSize = 3)   # 輪郭線抽出
    kernel = np.ones((3, 3), np.uint8)
    outLineImage = cv2.dilate(canny_edges, kernel, iterations=1)
    #outLineImage = cv2.erode(dilated_edges, kernel, iterations=1)

    cv2.imwrite("/home/abababam1/outLine.png", outLineImage)    # ファイル保存

    houghPList, mainlines = hough_lines_p(image2, outLineImage, params)  # 確率的ハフ変換による直線抽出
    #cv2.imwrite("./result_houghP.png", image2)        # ファイル保存
    cross_points = draw_cross_points(image2, houghPList, params)   # 直線リストから交点を描画
    cv2.imwrite("/home/abababam1/result_houghP_cross.png", image2)  # ファイル保存
    
    # 正方形の頂点をピックアップ
    squares = find_squares(cross_points, params, cropbox)

    # 正方形でクロップ
    cropped_images = crop_squares(image, squares)

    # 結果を保存
    for i, cropped_image in enumerate(cropped_images.values()):
        # 罫線を白塗り
        image = detect_line_in_char(cropped_image)
        
        os.makedirs(save_path, exist_ok=True)
        output_path = f'{save_path}'+'/'+'{:05d}.png'.format(i)
        cv2.imwrite(output_path, image)
        print(f"正方形でクロップされた画像が {output_path} に保存されました")

if __name__ == '__main__':
    test()

# %%
def point_line_to_2D(cross_points, params):
    
    muki = params['muki']
    nchars = params['nchars']
    ncols = params['ncols']
    char_width = params['char_width']
    sep_width = params['sep_width']
    
    # ピクセルに変換する
    dpi = 600
    char_size_px = int((char_width / 2.54) * dpi)
    sep_size_px = int((sep_width / 2.54) * dpi)
    
    if muki == 'tate':
        x_clusters = (ncols + 1) * 2
        y_clusters = nchars + 1
        min_x_cluster = find_min_x_cluster(cross_points, params)
        min_y_cluster = find_min_y_cluster(cross_points, params)
        mean_adjusted_x_cluster = mean_squared_x(min_x_cluster, char_size_px)
        mean_adjusted_y_cluster = mean_squared_y(min_y_cluster, char_size_px)
    
    rows = len(min_x_cluster)
    cols = len(min_y_cluster)
    cross_points_2D = np.zeros((rows, cols))
    
    for i in range(len(mean_adjusted_x_cluster)):
        for j in range(len(mean_adjusted_y_cluster)):
            cross_points_2D[i][j] = (mean_adjusted_x_cluster[i], mean_adjusted_y_cluster[j])
    return cross_points_2D

# %%
def kd_search(cross_points, cross_points_2D, params):
    
    
    knn_model = NearestNeighbors(n_neighbors=1, algorithm='ball_tree').fit(cross_points_2D) 
    distances, indices = knn_model.kneighbors([point])

    print(data[indices[0]][0])

# %%
import numpy as np
from sklearn.cluster import KMeans

def find_min_y_cluster(points, n_clusters):
    
    # 座標のリストをnumpy配列に変換
    points = np.array(points)
    
    # y座標のみを取り出してクラスタリングを実行
    y_coords = points[:, 1].reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(y_coords)
    
    # 各クラスタのy座標の平均値を計算
    cluster_labels = kmeans.labels_
    clusters = [points[cluster_labels == i] for i in range(n_clusters)]
    mean_y_values = [np.mean(cluster[:, 1]) for cluster in clusters]
    
    # y座標の平均値が最小のクラスタを選ぶ
    min_y_cluster_index = np.argmin(mean_y_values)
    min_y_cluster = clusters[min_y_cluster_index]
    
    return min_y_cluster

def find_min_x_cluster(points, n_clusters):
    
    # 座標のリストをnumpy配列に変換
    points = np.array(points)
    
    # x座標のみを取り出してクラスタリングを実行
    x_coords = points[:, 0].reshape(-1, 1)
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(x_coords)
    
    # 各クラスタのx座標の平均値を計算
    cluster_labels = kmeans.labels_
    clusters = [points[cluster_labels == i] for i in range(n_clusters)]
    mean_x_values = [np.mean(cluster[:, 0]) for cluster in clusters]
    
    # x座標の平均値が最小のクラスタを選ぶ
    min_x_cluster_index = np.argmin(mean_x_values)
    min_x_cluster = clusters[min_x_cluster_index]
    
    return min_x_cluster

# %%
def mean_squared_x(point_cluster, char_size_px):
    distances = []
    point_cluster = sorted(point_cluster, key=lambda point: point[0])
    i_previous = point_cluster[0][0]
    for i in range(1, len(point_cluster)):
        distance = abs(np.linalg.norm(point_cluster[i][0] - i_previous) - char_size_px)
        distances.append(distance)
        i_previous = point_cluster[i][0]
    distance_mean = np.mean(distances)
    
    labels = point_cluster.labels_
    unique_labels = set(labels)
    for label in unique_labels:
        if label == -1:
            continue
        cluster_indices = np.where(labels == label)[0]
        adjusted_points[cluster_indices, 0] += distance_mean
    return adjusted_points
    
def mean_squared_y(point_cluster, char_size_px):
    distances = []
    point_cluster = sorted(point_cluster, key=lambda point: point[1])
    i_previous = point_cluster[0][1]
    for i in range(1, len(point_cluster)):
        distance = abs(np.linalg.norm(point_cluster[i][1] - i_previous) - char_size_px)
        distances.append(distance)
        i_previous = point_cluster[i][1]
    distance_mean = np.mean(distances)
    
    labels = point_cluster.labels_
    unique_labels = set(labels)
    for label in unique_labels:
        if label == -1:
            continue
        cluster_indices = np.where(labels == label)[0]
        adjusted_points[cluster_indices, 1] += distance_mean
    return adjusted_points
